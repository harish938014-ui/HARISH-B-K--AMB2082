# %%
s = input("Enter a string: ")
print("Length of the string:", len(s))
# Out:
# Enter a string: harish
# Length of the string: 6

# %%
s = input("Enter a string: ")
rev = ""

for ch in s:
    rev = ch + rev

print("Reversed string:", rev)
# Out:
# Enter a string: my name is harish
# Reversed string: hsirah si eman ym

# %%
s = input("Enter a string: ")
rev = s[::-1]

if s == rev:
    print("Palindrome")
else:
    print("Not a Palindrome")
# Out:
# Enter a string: hadag
# Not a Palindrome

# %%
s = input("Enter a string: ")
result = ""

for ch in s:
    if 'a' <= ch <= 'z':
        result += chr(ord(ch) - 32)
    else:
        result += ch

print("Uppercase string:", result)
# Out:
# Enter a string: gayithra
# Uppercase string: GAYITHRA

# %%
numbers = list(map(int, input("Enter numbers: ").split()))

n = len(numbers) + 1
expected_sum = n * (n + 1) // 2
actual_sum = sum(numbers)

missing_number = expected_sum - actual_sum
print("Missing number:", missing_number)
# Out:
# Enter numbers: 1 3
# Missing number: 2

# %%
numbers = list(map(int, input("Enter numbers separated by space: ").split()))

for i in range(len(numbers)):
    if numbers[i] < 0:
        numbers[i] = 0

print("Updated list:", numbers)
# Out:
# Enter numbers separated by space: 1 2 3 4 5 6 7 8 9
# Updated list: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
s = input("Enter a sentence: ")
words = s.split()
freq = {}

for w in words:
    freq[w] = freq.get(w, 0) + 1

print("Most frequent word:", max(freq, key=freq.get))
# Out:
# Enter a sentence: my name is harish and my sister name is gayitra
# Most frequent word: my

# %%
lst = list(map(int, input("Enter numbers: ").split()))
freq = {}

for num in lst:
    freq[num] = freq.get(num, 0) + 1

print(freq)
# Out:
# Enter numbers:  1
# {1: 1}

# %%
sentence = input("Enter a sentence: ")

vowels = "aeiouAEIOU"
words = sentence.split()

for word in words:
    count = 0
    for ch in word:
        if ch in vowels:
            count += 1
    print(word, ":", count)
# Out:
# Enter a sentence: harish is good in politics
# harish : 2
# is : 1
# good : 2
# in : 1
# politics : 3
