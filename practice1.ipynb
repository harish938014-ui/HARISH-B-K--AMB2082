# %%
a=10
if(a>5):
    print("10 is greater than 5")
# Out:
# 10 is greater than 5

# %%
day="tuesday"
if(day=="saturday"):
    print("colourdress")
else:
    print("uniform")
# Out:
# uniform

# %%
name="harish"
age=22
print("my name is",name,"and age is",age)
# Out:
# my name is harish and age is 22

# %%
name="harish"
age=22
print("my name is {} and age is {}".format (name,age))
# Out:
# my name is harish and age is 22

# %%
name="Bhagavan"
age=22
print("my name is {1} and age is {0}".format (age,name))
# Out:
# my name is Bhagavan and age is 22

# %%
a=10
b=20
if(a>b):
  print("a is greater than b".format(a,b))
else:
  print("b is greater than a".format(b,a))
# Out:
# b is greater than a

# %%
a=10
b=20
if(a>b):
  print("{}is greater than {}".format(a,b))
else:
  print("{} is greater than {}".format(b,a))
# Out:
# 20 is greater than 10

# %%
a=float(input("enter a number"))
print(a)
print(type(a))
# Out:
# enter a number8
# 8.0
# <class 'float'>

# %%
RF=float(input("enter rainfall in mm"))
if(RF>=500):
  print("rainfall suitable for paddy")
else:
  print("rainfall suitable for millets")
# Out:
# enter rainfall in mm55
# rainfall suitable for millets

# %%
temp=float(input("enter temperature in celcius"))
if(temp>=25):
  print("temperature is good for crop growth")
else:
  print("temperature is not suitable for crop growth")
# Out:
# enter temperature in celcius27
# temperature is good for crop growth
