# %%
marks={
    "maths":85,
    "science":90,
}
print(marks)
# Out:
# {'maths': 85, 'science': 90}

# %%
for i in range(3):
  for j in range(3):
    print("*",end=" ")
  print()
# Out:
# * * *
# * * *
# * * *

# %%
num=7
if num%2==0:
  print("irrigation day")
else:
  print("rest day")
# Out:
# rest day

# %%
num=7
if num%3==0:
  print("irrigation day")
else:
  print("rest day")
# Out:
# rest day

# %%
temp=float(input("enter a temperature"))
if(temp>25):
  print("temperature is good for crop growth")
else:
    print("temperature is not good for crop growth")

# %%
rainfall=float(input("enter a rainfall in mm"))
if(rainfall>200):
  print("rainfall is good for crop growth")
else:
    print("rainfall is not good for crop growth")

# %%
marks={
    "maths":85,
    "science":90,
    "biology":78,
}
print(total marks)
